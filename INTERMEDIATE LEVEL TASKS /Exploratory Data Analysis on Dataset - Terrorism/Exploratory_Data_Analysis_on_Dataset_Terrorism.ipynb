# %%
# Importing Libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Reading Data set
data=pd.read_csv('/content/globalterrorismdb_0718dist.csv', encoding ='latin1')
data.head()
# Out:
# <ipython-input-2-baa99b42c699>:2: DtypeWarning: Columns (4,31,33,61,62,63,76,79,90,92,94,96,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('/content/globalterrorismdb_0718dist.csv', encoding ='latin1')
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      0.0       0.0      0.0     0.0      NaN
# 1      0.0       1.0      1.0     1.0      NaN
# 2     -9.0      -9.0      1.0     1.0      NaN
# 3     -9.0      -9.0      1.0     1.0      NaN
# 4     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
# Describing the data
data.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  7.741300e+04  77413.000000  77413.000000  77413.000000  77413.000000
# mean   1.988737e+11   1988.671011      6.459303     15.333562      0.025655
# std    7.717344e+08      7.717004      3.397142      8.824209      0.158104
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.983072e+11   1983.000000      4.000000      8.000000      0.000000
# 50%    1.989063e+11   1989.000000      6.000000     15.000000      0.000000
# 75%    1.994122e+11   1994.000000      9.000000     23.000000      0.000000
# max    2.005011e+11   2005.000000     12.000000     31.000000      1.000000
#
#             country        region      latitude     longitude   specificity  \
# count  77413.000000  77413.000000  73556.000000  7.355500e+04  77412.000000
# mean     145.267152      5.915621     19.310514 -1.178813e+03      1.431923
# std      135.432426      3.190920     23.737009  3.177826e+05      1.095451
# min        4.000000      1.000000    -53.154613 -8.618590e+07      1.000000
# 25%       61.000000      3.000000      6.242026 -7.515143e+01      1.000000
# 50%      110.000000      6.000000     19.371887  1.231572e+00      1.000000
# 75%      183.000000      8.000000     38.290490  3.550351e+01      1.000000
# max     1003.000000     12.000000     74.633553  1.793667e+02      5.000000
#
#        ...     ransomamt   ransomamtus    ransompaid  ransompaidus  \
# count  ...  8.170000e+02  1.150000e+02  2.950000e+02    111.000000
# mean   ...  3.332860e+06  4.605453e+05  7.297225e+05   1114.225225
# std    ...  3.644035e+07  1.809967e+06  3.469721e+06   6438.343489
# min    ... -9.900000e+01 -9.900000e+01 -9.900000e+01    -99.000000
# 25%    ...  0.000000e+00  0.000000e+00  0.000000e+00      0.000000
# 50%    ...  1.200000e+04  0.000000e+00  0.000000e+00      0.000000
# 75%    ...  5.000000e+05  0.000000e+00  7.750000e+04      0.000000
# max    ...  1.000000e+09  1.500000e+07  4.100000e+07  48000.000000
#
#        hostkidoutcome    nreleased       INT_LOG      INT_IDEO      INT_MISC  \
# count     2519.000000  2106.000000  77412.000000  77412.000000  77412.000000
# mean         3.853116   -10.161918     -3.799114     -3.754818      0.126156
# std          1.965312    61.001350      4.508034      4.565426      0.784106
# min          1.000000   -99.000000     -9.000000     -9.000000     -9.000000
# 25%          2.000000     0.000000     -9.000000     -9.000000      0.000000
# 50%          4.000000     1.000000      0.000000      0.000000      0.000000
# 75%          5.500000     2.000000      0.000000      0.000000      0.000000
# max          7.000000   856.000000      1.000000      1.000000      1.000000
#
#             INT_ANY
# count  77412.000000
# mean      -3.000065
# std        4.528913
# min       -9.000000
# 25%       -9.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 77 columns]

# %%
# Data Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77413 entries, 0 to 77412
# Columns: 135 entries, eventid to related
# dtypes: float64(66), int64(11), object(58)
# memory usage: 79.7+ MB

# %%
# Data Types
data.dtypes
# Out:
# eventid         int64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
#                ...
# INT_LOG       float64
# INT_IDEO      float64
# INT_MISC      float64
# INT_ANY       float64
# related        object
# Length: 135, dtype: object

# %%
# Data Set Columns
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %%
# Taking out required Columns for Analysis
data=data[['eventid', 'iyear', 'imonth', 'country', 'region','provstate','city','crit1', 'crit2', 'crit3','success', 'suicide', 'attacktype1','targtype1','natlty1','gname','guncertain1','claimed','weaptype1','nkill','nwound']]
data.head()
# Out:
#         eventid  iyear  imonth  country  region provstate           city  \
# 0  197000000001   1970       7       58       2       NaN  Santo Domingo
# 1  197000000002   1970       0      130       1   Federal    Mexico city
# 2  197001000001   1970       1      160       5    Tarlac        Unknown
# 3  197001000002   1970       1       78       8    Attica         Athens
# 4  197001000003   1970       1      101       4   Fukouka        Fukouka
#
#    crit1  crit2  crit3  ...  suicide  attacktype1  targtype1  natlty1  \
# 0      1      1      1  ...      0.0          1.0       14.0     58.0
# 1      1      1      1  ...      0.0          6.0        7.0     21.0
# 2      1      1      1  ...      0.0          1.0       10.0    217.0
# 3      1      1      1  ...      0.0          3.0        7.0    217.0
# 4      1      1      1  ...      0.0          7.0        7.0    217.0
#
#                                 gname guncertain1  claimed  weaptype1  nkill  \
# 0                              MANO-D         0.0      NaN       13.0    1.0
# 1  23rd of September Communist League         0.0      NaN       13.0    0.0
# 2                             Unknown         0.0      NaN       13.0    1.0
# 3                             Unknown         0.0      NaN        6.0    NaN
# 4                             Unknown         0.0      NaN        8.0    NaN
#
#    nwound
# 0     0.0
# 1     0.0
# 2     0.0
# 3     NaN
# 4     NaN
#
# [5 rows x 21 columns]

# %%
# Returning Number of Missing values
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# country            0
# region             0
# provstate        414
# city               0
# crit1              0
# crit2              0
# crit3              0
# success            1
# suicide            1
# attacktype1        1
# targtype1          1
# natlty1          470
# gname              1
# guncertain1      171
# claimed        66121
# weaptype1          1
# nkill           6272
# nwound          8909
# dtype: int64

# %%
# Combining Two Columns i.e., 'nkill' and 'nwound' into a new column 'casualities'
data['nkill']=data['nkill'].fillna(0)
data['nwound']=data['nwound'].fillna(0)
data['casualities']=data['nkill']+data['nwound']
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# country            0
# region             0
# provstate        414
# city               0
# crit1              0
# crit2              0
# crit3              0
# success            1
# suicide            1
# attacktype1        1
# targtype1          1
# natlty1          470
# gname              1
# guncertain1      171
# claimed        66121
# weaptype1          1
# nkill              0
# nwound             0
# casualities        0
# dtype: int64

# %%
data.describe()
# Out:
#             eventid         iyear        imonth       country        region  \
# count  7.741300e+04  77413.000000  77413.000000  77413.000000  77413.000000
# mean   1.988737e+11   1988.671011      6.459303    145.267152      5.915621
# std    7.717344e+08      7.717004      3.397142    135.432426      3.190920
# min    1.970000e+11   1970.000000      0.000000      4.000000      1.000000
# 25%    1.983072e+11   1983.000000      4.000000     61.000000      3.000000
# 50%    1.989063e+11   1989.000000      6.000000    110.000000      6.000000
# 75%    1.994122e+11   1994.000000      9.000000    183.000000      8.000000
# max    2.005011e+11   2005.000000     12.000000   1003.000000     12.000000
#
#               crit1        crit2         crit3       success       suicide  \
# count  77413.000000  77413.00000  77413.000000  77412.000000  77412.000000
# mean       0.986914      0.99004      0.883818      0.914458      0.006963
# std        0.113642      0.09930      0.320445      0.279689      0.083153
# min        0.000000      0.00000      0.000000      0.000000      0.000000
# 25%        1.000000      1.00000      1.000000      1.000000      0.000000
# 50%        1.000000      1.00000      1.000000      1.000000      0.000000
# 75%        1.000000      1.00000      1.000000      1.000000      0.000000
# max        1.000000      1.00000      1.000000      1.000000      1.000000
#
#         attacktype1     targtype1       natlty1   guncertain1       claimed  \
# count  77412.000000  77412.000000  76943.000000  77242.000000  11292.000000
# mean       3.109686      7.982987    128.378696      0.069263     -0.190577
# std        1.971918      6.777605     85.184150      0.253902      1.822129
# min        1.000000      1.000000      4.000000      0.000000     -9.000000
# 25%        2.000000      2.000000     61.000000      0.000000      0.000000
# 50%        3.000000      4.000000    113.000000      0.000000      0.000000
# 75%        3.000000     14.000000    185.000000      0.000000      0.000000
# max        9.000000     22.000000   1003.000000      1.000000      1.000000
#
#           weaptype1         nkill        nwound   casualities
# count  77412.000000  77413.000000  77413.000000  77413.000000
# mean       6.505800      2.152326      2.471678      4.624004
# std        2.286707     12.107931     50.069705     57.680527
# min        1.000000      0.000000      0.000000      0.000000
# 25%        5.000000      0.000000      0.000000      0.000000
# 50%        6.000000      0.000000      0.000000      1.000000
# 75%        6.000000      1.000000      0.000000      3.000000
# max       13.000000   1384.000000   8191.000000   9574.000000

# %%
print(f"""
There are {data.country.nunique()} Countries from {data.region.nunique()} Regions covered in the dataset terrorist attack data in {data.claimed.nunique()} years from {data.iyear.min()} to {data.iyear.max()}. Overall {data.index.nunique()} terrorist attacks are recorded here which caused about {data.casualities.sum()} Casualities Consisted of {data.nkill.sum()} Kills and {data.nwound.sum()} Wounded.
""")
# Out:
# There are 202 Countries from 12 Regions covered in the dataset terrorist attack data in 3 years from 1970 to 2005. Overall 77413 terrorist attacks are recorded here which caused about 357958.0 Casualities Consisted of 166618.0 Kills and 191340.0 Wounded.

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Adjusting the figure size
plt.subplots(figsize=(15,6))

# Creating the count plot with corrected syntax
sns.countplot(x='iyear', data=data, palette='RdYlGn_r', edgecolor=sns.color_palette('dark', 10))

# Rotating x-axis labels for better readability
plt.xticks(rotation=90)

# Adding a title to the plot
plt.title("Number of Terrorist Activities Each Year")

# Displaying the plot
plt.show()
# Out:
# <ipython-input-14-a9b9dfa23e6b>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='iyear', data=data, palette='RdYlGn_r', edgecolor=sns.color_palette('dark', 10))

# %%
yearc=data[['iyear','casualities']].groupby('iyear').sum()
yearc.plot(kind='bar',color='red',figsize=(15,6))
plt.title("Casualities")
plt.xlabel('Years',fontsize=15)
plt.ylabel('No. of Casualities',fontsize=15)
plt.show()

# %%
data['attacktype1'].value_counts().plot(kind='bar',figsize=(20,10),color='blue')
plt.xticks(rotation=50)
plt.xlabel('Attack Type',fontsize=20)
plt.ylabel('Number of attacks')
plt.title('Number of attacks')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Adjusting the figure size
plt.subplots(figsize=(20,10))

# Creating the count plot with corrected syntax
sns.countplot(x=data['targtype1'], order=data['targtype1'].value_counts().index, palette='gist_heat', edgecolor=sns.color_palette("crest"))

# Rotating x-axis labels for better readability
plt.xticks(rotation=90)

# Adding labels and title
plt.xlabel('Attack type', fontsize=20)
plt.ylabel('Count')
plt.title('Type of Attack')

# Displaying the plot
plt.show()
# Out:
# <ipython-input-18-10ba86c1e79d>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data['targtype1'], order=data['targtype1'].value_counts().index, palette='gist_heat', edgecolor=sns.color_palette("crest"))

# %%
plt.subplots(figsize=(15,6))
country_attacks = data.gname.value_counts()[:15].reset_index()
country_attacks.columns = ['gname', 'Total Attacks']
sns.barplot(x = country_attacks.gname, y = country_attacks['Total Attacks'], palette='OrRd_r', edgecolor=sns.color_palette('dark', 10))
plt.xticks(rotation = 90)
plt.title("Number of Total Attacks in Each Country")
plt.show()
# Out:
# <ipython-input-19-3d266d813f6d>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = country_attacks.gname, y = country_attacks['Total Attacks'], palette='OrRd_r', edgecolor=sns.color_palette('dark', 10))

# %%
sattk=data.success.value_counts()[:10]
sattk
# Out:
# Series([], Name: count, dtype: int64)

# %%
data.gname.value_counts()[1:11]
# Out:
# gname
# Shining Path (SL)                                   4510
# Farabundo Marti National Liberation Front (FMLN)    3351
# Irish Republican Army (IRA)                         2666
# Basque Fatherland and Freedom (ETA)                 1930
# Revolutionary Armed Forces of Colombia (FARC)       1563
# National Liberation Army of Colombia (ELN)          1256
# Liberation Tigers of Tamil Eelam (LTTE)             1139
# Palestinians                                        1125
# Kurdistan Workers' Party (PKK)                      1090
# New People's Army (NPA)                             1049
# Name: count, dtype: int64

# %% [markdown]
# # Conclusions
# There are 205 Countries from 12 Regions covered in the dataset terrorist attack data in 3 years from 1970 to 2017. Overall 181691 terrorist attacks are recorded here which caused about 935737.0 Casualities Consisted of 411868.0 Kills and 523869.0 Wounded.

# %% [markdown]
# 1.Taliban has done most of attacks
#
# 2.Most of the attacks were made in the year 2014
#
# 3.bombing type attack were used most of time
